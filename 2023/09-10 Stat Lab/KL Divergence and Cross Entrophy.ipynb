# %%
using Pkg
Pkg.add("StatsBase")
# Out:
#    Resolving package versions...
#     Updating `~/.julia/environments/v1.9/Project.toml`
#   [2913bbd2] + StatsBase v0.34.0
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`

# %%
Pkg.add("Random")
using Random
using Plots
# Out:
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`

# %%
v1 = rand(Float64,3)
v2 = rand(Float64,3)
# Out:
# 3-element Vector{Float64}:
#  0.32516294258761924
#  0.3757195464388383
#  0.8585506651488892

# %%
cross_entrophy = sum(-log.(v1).*v2)

# %%
v1=[0.1,0.5,0.4]
v2=[0.3,0.5,0.2]
[sum(-log2.(v1)),sum(-log2.(v2))]
# Out:
# 2-element Vector{Float64}:
#  5.6438561897747235
#  5.058893689053569

# %%
function neg_log2(x)
    -log2.(x)
end
x = [i/10 for i in 1:10]
y = neg_log2(x)
plot(x, y)
scatter!(x,y,title="Entrophy Function in Gross Looks Like This")

# %% [markdown]
# We can have a short view of what Entrophy may enconvy. Let's fix the value 0.5. The two value on the side sum up to something. The property of logrithmn function is it emplify
# the manitude of low value. So the shaper the probablity (close to 0), the higher this "surprise value". The less evenly distributed of the value they are, the higher the **entrophy**.
#
# Next you ask, is there exists entrophy for pdf of normal distribution?

# %%
#Pkg.add("Distributions")
using Random, Distributions
Random.seed!(123)
d = Normal()
x = Float64[i for i in 1:200]./200 .- 0.5
y = pdf.(d, v)
z = -log2.(y)
plot(x,y)
# Out:
# attempt to save state beyond implementation limit
# attempt to save state beyond implementation limit
# attempt to save state beyond implementation limit

# %%
plot(x, z)
# Out:
# attempt to save state beyond implementation limit
# attempt to save state beyond implementation limit
# attempt to save state beyond implementation limit

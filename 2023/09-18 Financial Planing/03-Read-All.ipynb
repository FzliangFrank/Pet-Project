# %%
import os
import re
pocket='bank-statement'
items=os.listdir(pocket)

statements=[
    pocket + '/' + item for item in items if re.search(r'\.pdf',item)
]
from src.bank_transaction_reader import BankTransactionReader as BtReader 
my_statements = BtReader.read(statements)
# Out:
# Read additional 8 tables.Total 8 tables populated.
# Read additional 7 tables.Total 15 tables populated.
# Read additional 8 tables.Total 23 tables populated.
# Read additional 7 tables.Total 30 tables populated.
# Read additional 8 tables.Total 38 tables populated.
# Read additional 7 tables.Total 45 tables populated.

# %%
# my_statements.to_csv('banks-data.csv', index = False)

# %%
from src.bank_transaction_analyser import BankTransactionAnalyser as bta
bank_statement=bta(my_statements)
# Out:
# cleaning complete.
# initialized

# %%
bank_statment_df = bank_statement.data.copy()
bank_statment_df.drop(axis=1, columns=["Month", "Week"], inplace=True)

# %%
# bank_statment_df.to_parquet("data/bank-data.parquet")

# %%
# sample ingestion pipe line for bankstatement
from sqlalchemy import create_engine
import psycopg2 
import io

from dotenv import load_dotenv
# create_engine(f'postgresql://{pg_usr}:{pg_pswd}@{host}:5432/{db}')
# Out:
# None

# %%
bank_statement.plotly_spending_period()

# %%
bank_statement.plotly_balance()
